# %%
import cv2
import matplotlib.pyplot as plt
import pySaliencyMap

# main
if __name__ == '__main__':
    # read
    img = cv2.imread('image/00001_origin.png')
    # initialize
    imgsize = img.shape
    img_width  = imgsize[1]
    img_height = imgsize[0]
    sm = pySaliencyMap.pySaliencyMap(img_width, img_height)
    # computation
    saliency_map = sm.SMGetSM(img)
    binarized_map = sm.SMGetBinarizedSM(img)
    salient_region = sm.SMGetSalientRegion(img)
    # visualize
#    plt.subplot(2,2,1), plt.imshow(img, 'gray')
    plt.subplot(2,2,1), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Input image')
#    cv2.imshow("input",  img)
    plt.subplot(2,2,2), plt.imshow(saliency_map, 'gray')
    plt.title('Saliency map')
#    cv2.imshow("output", map)
    plt.subplot(2,2,3), plt.imshow(binarized_map)
    plt.title('Binarilized saliency map')
#    cv2.imshow("Binarized", binarized_map)
    plt.subplot(2,2,4), plt.imshow(cv2.cvtColor(salient_region, cv2.COLOR_BGR2RGB))
    plt.title('Salient region')
#    cv2.imshow("Segmented", segmented_map)

    plt.show()
#    cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [array([[120.477356, 120.31076 , 110.920044, ...,  30.77945 ,  48.36084 ,
#          97.896576],
#        [120.47919 , 120.30502 , 110.82675 , ...,  10.848541,  29.678558,
#         100.401306],
#        [120.45773 , 120.30899 , 112.28604 , ...,  33.277527,  10.336609,
#         107.22604 ],
#        ...,
#        [ 70.132355,  74.91293 ,  93.388855, ..., 106.30588 , 110.86508 ,
#         116.246124],
#        [ 76.24133 ,  77.18924 ,  80.8869  , ..., 113.73596 , 114.26596 ,
#         114.93472 ],
#        [ 77.43317 ,  77.63666 ,  78.44263 , ..., 114.64142 , 114.70224 ,
#         114.78616 ]], dtype=float32), array([[ 24.213348,  24.379944,  33.77066 , ...,  95.30142 , 112.88281 ,
#         162.41855 ],
#        [ 24.211517,  24.385681,  33.863953, ...,  75.370514,  94.20053 ,
#         164.92328 ],
#        [ 24.232971,  24.381714,  32.404663, ...,  31.244446,  54.185364,
#         171.74802 ],
#        ...,
#        [ 33.577972,  28.797394,  10.321472, ..., 119.9086  , 124.467804,
#         129.84885 ],
#        [ 27.468994,  26.521088,  22.823425, ..., 127.338684, 127.86868 ,
#         128.53745 ],
#        [ 26.27716 ,  26.07367 ,  25.2677  , ..., 128.24414 , 128.30496 ,
#         128.38889 ]], dtype=float32), array([[ 36.687958 ,  39.24051  ,  35.97458  , ...,   7.186035 ,
#          73.37396  , 128.03549  ],
#        [ 34.1214   ,  39.547485 ,  49.14749  , ...,   4.3650208,
#          63.517853 , 119.479095 ],
#        [ 28.790192 ,  39.4628   ,  72.47226  , ...,  13.978058 ,
#          52.229156 , 104.48605  ],
#        ...,
#        [ 38.760284 ,   5.694092 ,  12.999756 , ...,   8.6562195,
#          49.64737  , 117.8801   ],
#        [ 35.015015 ,  12.0672   ,  10.147491 , ...,  78.28995  ,
#          94.90088  , 123.23874  ],
#        [ 32.06595  ,  17.735413 ,  14.656982 , ..., 104.71704  ,
#         112.37137  , 125.61099  ]], dtype=float32), array([[207.16975 , 209.7223  , 206.45638 , ..., 106.686356, 172.87428 ,
#         227.53581 ],
#        [204.6032  , 210.02928 , 219.62929 , ..., 103.86534 , 163.01817 ,
#         218.97942 ],
#        [199.27199 , 209.9446  , 242.95406 , ..., 113.47838 , 151.72948 ,
#         203.98637 ],
#        ...,
#        [155.02705 , 121.96086 , 129.26653 , ...,  14.486572,  26.504578,
#          94.737305],
#        [151.28178 , 128.33397 , 126.41426 , ...,  55.147156,  71.75809 ,
#         100.09595 ],
#        [148.33272 , 134.00218 , 130.92375 , ...,  81.57425 ,  89.22858 ,
#         102.4682  ]], dtype=float32), array([[289.62286 , 235.76884 ,  17.601303, ...,  44.300095, 109.09148 ,
#         203.94518 ],
#        [293.2519  , 239.85017 ,  13.632996, ...,  32.070084, 110.25949 ,
#         213.19365 ],
#        [299.12036 , 244.3256  ,   4.958267, ...,  27.235626, 119.800735,
#         225.7953  ],
#        ...,
#        [228.6186  , 177.70738 ,  40.816498, ...,  75.9301  ,  56.049637,
#          24.782654],
#        [193.3196  , 153.33192 ,  13.561996, ...,  21.734833,   9.488403,
#          43.866302],
#        [176.37306 , 142.26332 ,  41.680252, ...,   8.714569,  16.216705,
#          55.026917]], dtype=float32), array([[325.13934  , 271.28534  ,  53.117798 , ...,  58.13138  ,
#           6.6600037, 101.5137   ],
#        [328.7684   , 275.36667  ,  49.14949  , ...,  70.36139  ,
#           7.828018 , 110.76218  ],
#        [334.63687  , 279.8421   ,  40.474762 , ...,  75.19585  ,
#          17.369263 , 123.36383  ],
#        ...,
#        [284.05292  , 233.14168  ,  14.617798 , ...,  32.888336 ,
#          13.007874 ,  67.82442  ],
#        [248.75389  , 208.76622  ,  68.99629  , ...,  21.30693  ,
#          33.55336  ,  86.908066 ],
#        [231.80736  , 197.69762  ,  97.11455  , ...,  51.756332 ,
#          59.25847  ,  98.06868  ]], dtype=float32), array([[ 36.836853,  37.30542 ,  39.045258, ..., 150.70612 , 152.64365 ,
#         149.02203 ],
#        [ 36.862885,  37.779205,  40.69394 , ..., 110.65521 , 136.74911 ,
#         126.401825],
#        [ 36.862396,  37.633972,  43.75836 , ...,  17.487946,  62.105164,
#          87.558075],
#        ...,
#        [ 37.440613,  50.899567,  57.93338 , ...,  95.56171 ,  91.019226,
#          89.48035 ],
#        [ 38.897278,  40.845337,  43.842987, ...,  88.754   ,  88.40027 ,
#          87.772064],
#        [ 39.57962 ,  39.817993,  40.366577, ...,  87.39441 ,  87.38269 ,
#          87.375916]], dtype=float32), array([[131.55397 , 132.02254 , 133.76237 , ..., 157.42068 , 159.35822 ,
#         155.7366  ],
#        [131.58    , 132.49632 , 135.41106 , ..., 117.36978 , 143.46368 ,
#         133.1164  ],
#        [131.57951 , 132.35109 , 138.47548 , ...,  24.202515,  68.81973 ,
#          94.272644],
#        ...,
#        [112.832245, 126.2912  , 133.32501 , ..., 143.49168 , 138.9492  ,
#         137.41032 ],
#        [114.28891 , 116.23697 , 119.23462 , ..., 136.68398 , 136.33025 ,
#         135.70204 ],
#        [114.97125 , 115.209625, 115.75821 , ..., 135.32439 , 135.31267 ,
#         135.3059  ]], dtype=float32), array([[138.2071   , 128.87233  , 102.3936   , ...,  73.98453  ,
#         101.03195  , 120.6062   ],
#        [137.42513  , 140.91283  , 105.00395  , ...,  37.263763 ,
#          63.846527 ,  84.71585  ],
#        [134.34383  , 148.13719  , 143.7842   , ...,   5.0043945,
#           5.924774 ,  38.27951  ],
#        ...,
#        [100.92493  ,  83.272675 ,  81.388306 , ...,  19.01445  ,
#          25.83281  ,  82.7448   ],
#        [110.24164  , 117.336426 , 103.03284  , ..., 130.2076   ,
#         119.59709  , 134.16347  ],
#        [116.269226 , 121.464355 , 119.839294 , ..., 159.7123   ,
#         153.1551   , 146.40578  ]], dtype=float32), array([[238.40593 , 229.07115 , 202.59242 , ..., 173.57483 , 200.62225 ,
#         220.1965  ],
#        [237.62395 , 241.11165 , 205.20277 , ..., 136.85406 , 163.43683 ,
#         184.30615 ],
#        [234.54265 , 248.33601 , 243.98302 , ...,  94.5859  , 105.51507 ,
#         137.86981 ],
#        ...,
#        [132.54651 , 114.89426 , 113.00989 , ...,  15.057831,  21.87619 ,
#          78.78818 ],
#        [141.86322 , 148.95801 , 134.65442 , ..., 126.25098 , 115.64047 ,
#         130.20685 ],
#        [147.89081 , 153.08594 , 151.46088 , ..., 155.75568 , 149.19849 ,
#         142.44916 ]], dtype=float32), array([[244.45583 , 201.23344 , 103.16695 , ..., 110.90656 , 123.09983 ,
#         138.19623 ],
#        [255.44728 , 191.28108 ,  50.46173 , ...,  71.26823 , 124.88732 ,
#         134.57501 ],
#        [261.85052 , 208.29814 ,  75.0809  , ...,  25.851952, 101.9656  ,
#         160.12189 ],
#        ...,
#        [169.45999 , 167.2472  ,  43.01996 , ...,  86.732254,  67.01544 ,
#          20.796295],
#        [136.95428 , 174.92029 , 147.13193 , ...,  28.374542,  24.150665,
#          52.71805 ],
#        [125.37863 , 123.050964, 132.22308 , ..., 125.52484 , 121.47055 ,
#         117.550385]], dtype=float32), array([[209.94841  , 166.72603  ,  68.65953  , ...,  38.56398  ,
#          26.370712 ,  11.2743225],
#        [220.93987  , 156.77367  ,  15.954315 , ...,  78.20232  ,
#          24.583221 ,  14.895538 ],
#        [227.3431   , 173.79073  ,  40.573486 , ..., 123.61859  ,
#          47.504944 ,  10.651337 ],
#        ...,
#        [165.62518  , 163.41238  ,  39.18515  , ...,  62.599655 ,
#          42.882843 ,   3.3363037],
#        [133.11948  , 171.08548  , 143.29712  , ...,  52.50714  ,
#          48.283264 ,  76.85065  ],
#        [121.54382  , 119.216156 , 128.38828  , ..., 149.65744  ,
#         145.60315  , 141.68298  ]], dtype=float32), array([[ 88.57062  ,  88.652985 ,  89.134125 , ..., 268.55676  ,
#         248.45131  , 239.23268  ],
#        [ 88.416046 ,  87.71277  ,  82.97681  , ..., 135.31715  ,
#         142.71465  , 147.02968  ],
#        [ 88.39978  ,  87.607086 ,  82.24069  , ...,  36.719467 ,
#          11.484161 ,  31.223038 ],
#        ...,
#        [  2.7357788,   2.3047485,  12.814789 , ...,   5.014038 ,
#           2.2437134,   0.7151489],
#        [  9.318634 ,   8.55722  ,   6.963928 , ...,  10.434753 ,
#          10.286438 ,  10.208496 ],
#        [ 10.6562195,  10.778137 ,  11.020294 , ...,   9.986572 ,
#           9.948914 ,   9.92807  ]], dtype=float32), array([[143.05417  , 143.13654  , 143.61768  , ..., 262.37494  ,
#         242.26949  , 233.05086  ],
#        [142.8996   , 142.19632  , 137.46036  , ..., 129.13533  ,
#         136.53282  , 140.84785  ],
#        [142.88333  , 142.09064  , 136.72424  , ...,  42.90129  ,
#           5.3023376,  25.041214 ],
#        ...,
#        [106.558014 , 111.59854  , 122.10858  , ..., 142.67105  ,
#         139.90073  , 138.37216  ],
#        [ 99.97516  , 100.73657  , 102.329865 , ..., 127.22226  ,
#         127.370575 , 127.44852  ],
#        [ 98.63757  ,  98.515656 ,  98.2735   , ..., 127.67044  ,
#         127.7081   , 127.72894  ]], dtype=float32), array([[135.0994  , 131.08606 , 130.68979 , ..., 210.42638 , 197.2896  ,
#         194.20659 ],
#        [135.2443  , 126.76282 ,  99.98636 , ...,  26.798569,  44.298416,
#          56.45787 ],
#        [141.80426 , 135.09369 ,  99.05203 , ...,  87.77478 ,  54.1615  ,
#          40.889297],
#        ...,
#        [ 34.112183,  25.919922,  16.200195, ...,  62.22    ,  67.55255 ,
#          71.22815 ],
#        [ 99.58438 ,  99.4205  , 100.867004, ..., 193.31277 , 184.93738 ,
#         180.11356 ],
#        [123.57184 , 126.819916, 131.87756 , ..., 177.29898 , 171.69183 ,
#         168.38123 ]], dtype=float32), array([[210.55115 , 206.53781 , 206.14154 , ..., 285.03625 , 271.89948 ,
#         268.81647 ],
#        [210.69604 , 202.21457 , 175.43811 , ..., 101.40843 , 118.90828 ,
#         131.06773 ],
#        [217.25601 , 210.54544 , 174.50378 , ...,  13.164917,  20.448364,
#          33.720566],
#        ...,
#        [155.7132  , 147.52094 , 137.80121 , ..., 153.66675 , 158.9993  ,
#         162.6749  ],
#        [221.1854  , 221.02151 , 222.46802 , ..., 284.75952 , 276.38412 ,
#         271.5603  ],
#        [245.17285 , 248.42093 , 253.47858 , ..., 268.74573 , 263.13858 ,
#         259.82797 ]], dtype=float32), array([[186.49072 , 176.10205 , 157.47708 , ..., 180.3098  , 170.48863 ,
#         163.94405 ],
#        [171.49304 , 138.9231  ,  64.36815 , ...,  16.960007,  34.41156 ,
#          45.80905 ],
#        [181.01901 , 146.65683 ,  61.38141 , ...,  26.250122,  25.884583,
#          55.127594],
#        ...,
#        [152.99295 , 110.7536  ,  14.522079, ...,  71.23337 ,  51.370003,
#          39.38645 ],
#        [180.07977 , 175.84528 , 167.64813 , ..., 150.24966 , 148.44196 ,
#         148.17053 ],
#        [239.33554 , 259.59744 , 308.08536 , ..., 351.88132 , 344.2258  ,
#         339.26422 ]], dtype=float32), array([[106.8134   ,  96.42473  ,  77.79976  , ...,   6.73291  ,
#           3.0882568,   9.632843 ],
#        [ 91.81572  ,  59.245773 ,  15.309174 , ..., 156.61688  ,
#         139.16533  , 127.76784  ],
#        [101.34169  ,  66.97951  ,  18.295914 , ..., 199.82701  ,
#         147.6923   , 118.449295 ],
#        ...,
#        [104.59071  ,  62.351364 ,  33.880157 , ...,  78.16737  ,
#          58.30401  ,  46.320457 ],
#        [131.67754  , 127.44304  , 119.245895 , ..., 143.31566  ,
#         141.50795  , 141.23653  ],
#        [190.9333   , 211.1952   , 259.6831   , ..., 344.94733  ,
#         337.2918   , 332.3302   ]], dtype=float32), array([[ 36.256226,  36.720062,  38.4599  , ..., 150.39232 , 152.3336  ,
#         148.69572 ],
#        [ 36.28192 ,  37.0636  ,  41.611023, ...,  71.78987 ,  87.34715 ,
#         126.29826 ],
#        [ 36.27765 ,  37.20688 ,  38.805756, ...,  31.2267  ,  38.79048 ,
#          87.32045 ],
#        ...,
#        [ 36.957672,  28.487549,  34.020905, ...,  97.54965 ,  94.1514  ,
#          89.08768 ],
#        [ 38.414276,  38.924896,  41.8508  , ...,  88.05582 ,  87.505066,
#          87.379395],
#        [ 39.09668 ,  39.335083,  39.883667, ...,  87.00171 ,  86.99011 ,
#          86.983246]], dtype=float32), array([[130.96147 , 131.42531 , 133.16515 , ..., 157.00865 , 158.94994 ,
#         155.31206 ],
#        [130.98717 , 131.76884 , 136.31627 , ...,  78.406204,  93.963486,
#         132.9146  ],
#        [130.9829  , 131.91212 , 133.511   , ...,  37.843033,  45.406815,
#          93.93678 ],
#        ...,
#        [112.285736, 103.81561 , 109.34897 , ..., 145.45055 , 142.05229 ,
#         136.98857 ],
#        [113.74234 , 114.25296 , 117.17886 , ..., 135.95671 , 135.40596 ,
#         135.28029 ],
#        [114.42474 , 114.66315 , 115.21173 , ..., 134.9026  , 134.891   ,
#         134.88414 ]], dtype=float32), array([[137.75441 , 128.32887 , 101.80104 , ...,  73.75285 , 100.761795,
#         120.38927 ],
#        [136.96483 , 127.084335, 131.49974 , ...,  12.395309,  48.210373,
#          84.64601 ],
#        [133.85927 , 132.28844 , 143.70457 , ...,  43.866714,  18.892822,
#          38.184555],
#        ...,
#        [100.43335 ,  72.24213 ,  42.273132, ...,  59.60869 ,  96.59346 ,
#          82.33241 ],
#        [109.71225 ,  91.60205 ,  88.045654, ..., 148.82509 , 154.35426 ,
#         133.74171 ],
#        [115.77768 , 120.94232 , 119.31091 , ..., 159.29942 , 152.74257 ,
#         145.99333 ]], dtype=float32), array([[238.44753 , 229.02199 , 202.49416 , ..., 173.83426 , 200.8432  ,
#         220.47067 ],
#        [237.65794 , 227.77745 , 232.19286 , ...,  87.6861  , 148.29178 ,
#         184.72742 ],
#        [234.55238 , 232.98155 , 244.39769 , ...,  56.21469 , 118.97423 ,
#         138.26596 ],
#        ...,
#        [132.27081 , 104.07959 ,  74.110596, ...,  55.632828,  92.6176  ,
#          78.35655 ],
#        [141.54971 , 123.439514, 119.88312 , ..., 144.84923 , 150.3784  ,
#         129.76585 ],
#        [147.61514 , 152.77979 , 151.14838 , ..., 155.32356 , 148.76671 ,
#         142.01747 ]], dtype=float32), array([[244.93602  , 201.51659  , 103.13258  , ..., 111.26402  ,
#         123.50391  , 138.62231  ],
#        [255.93813  , 223.28249  , 110.090195 , ...,  23.73294  ,
#          64.90675  , 135.06564  ],
#        [262.27313  , 216.31642  ,  77.84071  , ...,   2.4988556,
#          95.36058  , 160.4881   ],
#        ...,
#        [169.40448  ,  60.40753  , 101.556076 , ...,  74.63899  ,
#          40.262634 ,  21.008377 ],
#        [136.66129  ,  52.963287 ,  14.116928 , ...,  43.8813   ,
#          60.95659  ,  52.30571  ],
#        [125.32312  , 122.93338  , 131.97913  , ..., 125.306656 ,
#         121.254684 , 117.33833  ]], dtype=float32), array([[210.21802  , 166.79858  ,  68.41458  , ...,  38.500015 ,
#          26.260132 ,  11.141724 ],
#        [221.22012  , 188.56448  ,  75.37219  , ..., 126.0311   ,
#          84.857285 ,  14.698395 ],
#        [227.55515  , 181.59842  ,  43.12271  , ..., 147.26518  ,
#          54.403458 ,  10.72406  ],
#        ...,
#        [165.58676  ,  56.589813 , 105.373795 , ...,  50.45256  ,
#          16.076202 ,   3.1780548],
#        [132.84357  ,  49.14557  ,  17.934647 , ...,  68.06773  ,
#          85.14302  ,  76.49214  ],
#        [121.5054   , 119.11566  , 128.1614   , ..., 149.49309  ,
#         145.44112  , 141.52477  ]], dtype=float32)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-87993009f0dd> in <module>()
#      13     sm = pySaliencyMap.pySaliencyMap(img_width, img_height)
#      14     # computation
# ---> 15     saliency_map = sm.SMGetSM(img)
#      16     binarized_map = sm.SMGetBinarizedSM(img)
#      17     salient_region = sm.SMGetSalientRegion(img)
#
# /media/qing/linux/repo/Traffic-sign-detection-and-classification/2018indin/trueone_2018indin/pySaliencyMap.py in SMGetSM(self, src)
#     189         ICM = self.ICMGetCM(IFM)
#     190         CCM = self.CCMGetCM(CFM_RG, CFM_BY)
# --> 191         OCM = self.OCMGetCM(OFM)
#     192         # adding all the conspicuity maps to form a saliency map
#     193         wi = pySaliencyMapDefs.weight_intensity
#
# /media/qing/linux/repo/Traffic-sign-detection-and-classification/2018indin/trueone_2018indin/pySaliencyMap.py in OCMGetCM(self, OFM)
#     169             # ??? why need this step, already normolization
#     170             # normalize
# --> 171             NOFM2 = self.SMNormalization(NOFM)
#     172             # accumulate
#     173             OCM += NOFM2
#
# /media/qing/linux/repo/Traffic-sign-detection-and-classification/2018indin/trueone_2018indin/pySaliencyMap.py in SMNormalization(self, src)
#     133     ## normalization specific for the saliency map model
#     134     def SMNormalization(self, src):
# --> 135         dst = self.SMRangeNormalize(src)
#     136         lmaxmean = self.SMAvgLocalMax(dst)
#     137         normcoeff = (1-lmaxmean)*(1- lmaxmean)
#
# /media/qing/linux/repo/Traffic-sign-detection-and-classification/2018indin/trueone_2018indin/pySaliencyMap.py in SMRangeNormalize(self, src)
#     107     ## ???  standard range normalization
#     108     def SMRangeNormalize(self, src):
# --> 109         minn, maxx, dummy1, dummy2 = cv2.minMaxLoc(src) # finds the global minimun and maximun in an array (value and location)
#     110         ## --  minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(src)
#     111         if maxx!= minn:
#
# TypeError: src is not a numpy array, neither a scalar

# %%
import cv2
import matplotlib.pyplot as plt
import pySaliencyMap

# main
if __name__ == '__main__':
    # read
    img = cv2.imread('image/00001_origin.png')
    # initialize
    imgsize = img.shape
    img_width  = imgsize[1]
    img_height = imgsize[0]
    sm = pySaliencyMap.pySaliencyMap(img_width, img_height)
    # computation
    saliency_map = sm.SMGetSM(img)
    binarized_map = sm.SMGetBinarizedSM(img)
    salient_region = sm.SMGetSalientRegion(img)
    # visualize
#    plt.subplot(2,2,1), plt.imshow(img, 'gray')
    plt.figure(figsize=[20,12])
    plt.subplot(2,2,1), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Input image')
#    cv2.imshow("input",  img)
    plt.subplot(2,2,2), plt.imshow(saliency_map, cmap = 'hot')
    plt.title('Saliency map_color')
#    cv2.imshow("output", map)
    plt.subplot(2,2,3), plt.imshow(binarized_map)
    plt.title('Binarilized saliency map')
#    cv2.imshow("Binarized", binarized_map)
    plt.subplot(2,2,4), plt.imshow(cv2.cvtColor(salient_region, cv2.COLOR_BGR2RGB))
    plt.title('Salient region')
#    cv2.imshow("Segmented", segmented_map)

    plt.show()
#    cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
import pySaliencyMap

# main
if __name__ == '__main__':
    # read
    img = cv2.imread('image/00001_origin.png')
    # initialize
    imgsize = img.shape
    img_width  = imgsize[1]
    img_height = imgsize[0]
    sm = pySaliencyMap.pySaliencyMap(img_width, img_height)
    # computation
    saliency_map = sm.SMGetSM(img)
    saliency_map_original = sm.SMGetSM_original(img)
    binarized_map = sm.SMGetBinarizedSM(img)
    salient_region = sm.SMGetSalientRegion(img)
    # visualize
#    plt.subplot(2,2,1), plt.imshow(img, 'gray')
    plt.figure(figsize=[20,12])
    plt.subplot(2,2,1), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Input image')
#    cv2.imshow("input",  img)
    plt.subplot(2,2,2), plt.imshow(saliency_map, cmap = 'hot')
    plt.title('Saliency map_color')
#    cv2.imshow("output", map)
    plt.subplot(2,2,3), plt.imshow(saliency_map_original, cmap = 'hot')
    plt.title('saliency_map_original')
#    cv2.imshow("Binarized", binarized_map)
    plt.subplot(2,2,4), plt.imshow(cv2.cvtColor(salient_region, cv2.COLOR_BGR2RGB))
    plt.title('Salient region')
#    cv2.imshow("Segmented", segmented_map)

    plt.show()
#    cv2.waitKey(0)
# cv2.destroyAllWindows()
